# %%
# ==========================================================
# Imports
# ==========================================================

from pathlib import Path

import numpy as np
import pandas as pd

from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
)

import warnings
warnings.filterwarnings("ignore")

SEED = 42

print("Imports Loaded ✓")
# Out:
# Imports Loaded ✓

# %%
from pathlib import Path
import pandas as pd

files = list(Path("/kaggle/input/notebooks").rglob("master_feature_engineered.parquet"))

print(files)

FEATURE_PATH = files[0]

master = pd.read_parquet(FEATURE_PATH)

print(master.shape)
master.head()
# Out:
# []
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_58/3702032691.py in <cell line: 0>()
#       6 print(files)
#       7
# ----> 8 FEATURE_PATH = files[0]
#       9
#      10 master = pd.read_parquet(FEATURE_PATH)
#
# IndexError: list index out of range

# %%
# ==========================================================
# Load Feature Engineered Dataset
# ==========================================================


FEATURE_PATH = Path(
    "/kaggle/input/notebooks/shri7ul/03_feature_engineering/master_feature_engineered.parquet"
)

master = pd.read_parquet(FEATURE_PATH)

print(master.shape)

master.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_58/3340420543.py in <cell line: 0>()
#      11 )
#      12
# ---> 13 master = pd.read_parquet(FEATURE_PATH)
#      14
#      15 print(master.shape)
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parquet.py in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     667     check_dtype_backend(dtype_backend)
#     668
# --> 669     return impl.read(
#     670         path,
#     671         columns=columns,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parquet.py in read(self, path, columns, filters, use_nullable_dtypes, dtype_backend, storage_options, filesystem, **kwargs)
#     256         if manager == "array":
#     257             to_pandas_kwargs["split_blocks"] = True
# ...
