# %%
import pandas as pd

# %%
df=pd.read_parquet("turns_candidate.parquet")

# %%
df.head(10)
# Out:
#   session_id                                           turn_uid  \
# 0    aaaedit  b42a03fee3a9fcf6b5d34f033d42896d409c6ad3fa2ab8...
# 1    aaaedit  76182f86f777c2402798e5c6f15f66d08b97a0fbd6c0a0...
# 2    aaaedit  c84d92d0b88ce952b2baac597b244712acc01bf3baaabc...
# 3    aaaedit  3c65ccc768a67021e334cb99fb62f0e8e8b4581678f93a...
# 4    aaaedit  5dbe6e8c9d8c9027b59d1309bdb59b2f18a61535efc314...
# 5    aaaedit  94f7b89d7324d975ac8db8c0fe8260d1f8cf0530cfca48...
# 6    aaaedit  91025ca7a77dc67f2ce243973e377381d6d81d0e06630b...
# 7    aaaedit  603e4a06653a900460a6f86c145dde00d5a3c8d8608fe8...
# 8    aaaedit  6aa46a419b5502f64eec58890d604da20ef9a5a91ebe88...
# 9    aaaedit  5a25f986984687e3ca4c6f4ec0a689b9beba76e4ef8600...
#
#                                       source_row_uid  turn_index  \
# 0  345f367256e99f6a79cd183db1ee716cac132302405c80...           0
# 1  4715f653dd108b64f2907e6d6e5f395d9e15b050cb00b5...           1
# ...

# %%
df1=pd.read_parquet("sessions_candidate.parquet")

# %%
df.head(10)
# Out:
#   session_id                                           turn_uid  \
# 0    aaaedit  b42a03fee3a9fcf6b5d34f033d42896d409c6ad3fa2ab8...
# 1    aaaedit  76182f86f777c2402798e5c6f15f66d08b97a0fbd6c0a0...
# 2    aaaedit  c84d92d0b88ce952b2baac597b244712acc01bf3baaabc...
# 3    aaaedit  3c65ccc768a67021e334cb99fb62f0e8e8b4581678f93a...
# 4    aaaedit  5dbe6e8c9d8c9027b59d1309bdb59b2f18a61535efc314...
# 5    aaaedit  94f7b89d7324d975ac8db8c0fe8260d1f8cf0530cfca48...
# 6    aaaedit  91025ca7a77dc67f2ce243973e377381d6d81d0e06630b...
# 7    aaaedit  603e4a06653a900460a6f86c145dde00d5a3c8d8608fe8...
# 8    aaaedit  6aa46a419b5502f64eec58890d604da20ef9a5a91ebe88...
# 9    aaaedit  5a25f986984687e3ca4c6f4ec0a689b9beba76e4ef8600...
#
#                                       source_row_uid  turn_index  \
# 0  345f367256e99f6a79cd183db1ee716cac132302405c80...           0
# 1  4715f653dd108b64f2907e6d6e5f395d9e15b050cb00b5...           1
# ...
